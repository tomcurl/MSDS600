# %%
import pandas as pd

df = pd.read_csv('/Users/thomascurl/Downloads/prepped_churn_data.csv', index_col='customerID')
df
# Out:
#             tenure  PhoneService  Contract  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG       1             0         1           29.85         29.85
# 5575-GNVDE      34             1        12           56.95       1889.50
# 3668-QPYBK       2             1         1           53.85        108.15
# 7795-CFOCW      45             0        12           42.30       1840.75
# 9237-HQITU       2             1         1           70.70        151.65
# ...            ...           ...       ...             ...           ...
# 6840-RESVB      24             1        12           84.80       1990.50
# 2234-XADUH      72             1        12          103.20       7362.90
# 4801-JZAZL      11             0         1           29.60        346.45
# 8361-LTMKD       4             1         1           74.40        306.60
# 3186-AJIEK      66             1        24          105.65       6844.50
#
#             Churn  Tenure_TotalCharges_ratio  TotalCharges_Tenure_ratio
# ...

# %%
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model

# %%
automl = setup(data = df, target = 'Churn',  fold_shuffle=True, imputation_type='iterative')
# Out:
# <style  type="text/css" >
# </style><table id="T_131f3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_131f3_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_131f3_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_131f3_row0_col1" class="data row0 col1" >6071</td>
#             </tr>
#             <tr>
#                         <th id="T_131f3_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_131f3_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_131f3_row1_col1" class="data row1 col1" >Churn</td>
#             </tr>
#             <tr>
#                         <th id="T_131f3_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
automl[6]
# Out:
# 6071

# %%
automl[14]

# %%
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_8d715_ th {
#           text-align: left;
# ...

# %%
best_model
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=6071, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
df.iloc[-2:-1].shape
# Out:
# (1, 8)

# %%
predict_model(best_model, df.iloc[-2:-1])
# Out:
#             tenure  PhoneService  Contract  MonthlyCharges  TotalCharges  \
# customerID
# 8361-LTMKD       4             1         1            74.4         306.6
#
#             Churn  Tenure_TotalCharges_ratio  TotalCharges_Tenure_ratio  \
# customerID
# 8361-LTMKD      1                   0.013046                      76.65
#
#             Label   Score
# customerID
# 8361-LTMKD      1  0.5797

# %%
df.iloc[-2:-1].shape
# Out:
# (1, 8)

# %%
save_model(best_model, 'LR')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Churn',
#                                        time_features=[])),
#                  ('imputer',
#                   Iterative_Imputer(add_indicator=False,
#                                     classifier=LGBMClassifier(boosting_type='gbdt',
#                                                               class_weight=None,
#                                                               colsample_bytree=...
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
# ...

# %%
new_data = df.iloc[-2:-1].copy()
new_data.drop('Churn', axis=1, inplace=True)
loaded_model.predict(df)
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
new_data = df.iloc[-2:-1].copy()
new_data.drop('Churn', axis=1, inplace=True)
loaded_model.predict(new_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-00e97777954a> in <module>
#       1 new_data = df.iloc[-2:-1].copy()
#       2 new_data.drop('Churn', axis=1, inplace=True)
# ----> 3 loaded_model.predict(new_data)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     305             Predicted class label per sample.
#     306         """
# --> 307         scores = self.decision_function(X)
#     308         if len(scores.shape) == 1:
#     309             indices = (scores > 0).astype(np.int)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     284         n_features = self.coef_.shape[1]
#     285         if X.shape[1] != n_features:
# --> 286             raise ValueError("X has %d features per sample; expecting %d"
# ...

# %%
automl[8]
# Out:
# False

# %%
automl[7]
# Out:
# {'acc': <pycaret.containers.metrics.classification.AccuracyMetricContainer at 0x7ffe3a4a3b80>,
#  'auc': <pycaret.containers.metrics.classification.ROCAUCMetricContainer at 0x7ffe3a4a3970>,
#  'recall': <pycaret.containers.metrics.classification.RecallMetricContainer at 0x7ffe3a4a3a60>,
#  'precision': <pycaret.containers.metrics.classification.PrecisionMetricContainer at 0x7ffe3a4a39d0>,
#  'f1': <pycaret.containers.metrics.classification.F1MetricContainer at 0x7ffe39247d00>,
#  'kappa': <pycaret.containers.metrics.classification.KappaMetricContainer at 0x7ffe39247e50>,
#  'mcc': <pycaret.containers.metrics.classification.MCCMetricContainer at 0x7ffe39247ee0>}

# %%
save_model(best_model, 'LR')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Churn',
#                                        time_features=[])),
#                  ('imputer',
#                   Iterative_Imputer(add_indicator=False,
#                                     classifier=LGBMClassifier(boosting_type='gbdt',
#                                                               class_weight=None,
#                                                               colsample_bytree=...
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
# ...

# %%
import pickle

with open('LR.pk', 'wb') as f:
    pickle.dump(best_model, f)

# %%
with open('LR.pk', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model

# %%
automl = setup(data = df, target = 'Churn',  fold_shuffle=True, imputation_type='iterative')
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            23:36:03
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                              Data Type
# tenure                         Numeric
# PhoneService               Categorical
# Contract                   Categorical
# MonthlyCharges                 Numeric
# TotalCharges                   Numeric
# Tenure_TotalCharges_ratio      Numeric
# TotalCharges_Tenure_ratio      Numeric
# Churn                            Label
# quit
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Read the documentation of setup to learn how to overwrite data types over the inferred types. setup function must run again before you continue modeling.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   tenure                     7032 non-null   int64
#  1   PhoneService               7032 non-null   int64
#  2   Contract                   7032 non-null   int64
#  3   MonthlyCharges             7032 non-null   float64
#  4   TotalCharges               7032 non-null   float64
#  5   Churn                      7032 non-null   int64
#  6   Tenure_TotalCharges_ratio  7032 non-null   float64
#  7   TotalCharges_Tenure_ratio  7032 non-null   float64
# dtypes: float64(4), int64(4)
# memory usage: 752.5+ KB

# %%
new_data = df.iloc[-2:-1].copy()
loaded_model.predict(new_data)
# Out:
# array([1])

# %%
import pickle

with open('LR.pk', 'wb') as f:
    pickle.dump(best_model, f)

# %%
with open('LR.pk', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model

# %%
automl = setup(data = df, target = 'Churn',  fold_shuffle=True, imputation_type='iterative')
# Out:
# <style  type="text/css" >
# </style><table id="T_e431c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e431c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e431c_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e431c_row0_col1" class="data row0 col1" >7829</td>
#             </tr>
#             <tr>
#                         <th id="T_e431c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e431c_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_e431c_row1_col1" class="data row1 col1" >Churn</td>
#             </tr>
#             <tr>
#                         <th id="T_e431c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
new_data = df.iloc[-2:-1].copy()
loaded_model.predict(new_data)
# Out:
# array([1])

# %%
loaded_lr = load_model('LR')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
predict_model(loaded_lr, new_data)
# Out:
#             tenure  PhoneService  Contract  MonthlyCharges  TotalCharges  \
# customerID
# 8361-LTMKD       4             1         1            74.4         306.6
#
#             Churn  Tenure_TotalCharges_ratio  TotalCharges_Tenure_ratio  \
# customerID
# 8361-LTMKD      1                   0.013046                      76.65
#
#             Label   Score
# customerID
# 8361-LTMKD      1  0.5797

# %%
from IPython.display import Code

Code('predict_churn.py')
# Out:
# predict_churn.py

# %%
# %run predict_churn.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'predict_churn.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-37-fcb7837ff9ac> in <module>
# ----> 1 get_ipython().run_line_magic('run', 'predict_churn.py')
#
# ...

# %%
from IPython.display import Code

Code('/Users/thomascurl/Downloads/predict_churn.py')
# Out:
# /Users/thomascurl/Downloads/predict_churn.py

# %%
import pandas as pd
from pycaret.classification import predict_model, load_model

def load_data(filepath):
    """
    Loads diabetes data into a DataFrame from a string filepath.
    """
    df = pd.read_csv(filepath, index_col='Patient number')
    return df


def make_predictions(df):
    """
    Uses the pycaret best model to make predictions on data in the df dataframe.
    """
    model = load_model('LDA')
    predictions = predict_model(model, data=df)
    predictions.rename({'Label': 'Diabetes_prediction'}, axis=1, inplace=True)
    predictions['Diabetes_prediction'].replace({1: 'Diabetes', 0: 'No diabetes'},
                                            inplace=True)
    return predictions['Diabetes_prediction']


if __name__ == "__main__":
    df = load_data('data/new_diabetes_data.csv')
    predictions = make_predictions(df)
    print('predictions:')
    print(predictions)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-6f85c13dc55e> in <module>
#      23
#      24 if __name__ == "__main__":
# ---> 25     df = load_data('data/new_diabetes_data.csv')
#      26     predictions = make_predictions(df)
#      27     print('predictions:')
#
# <ipython-input-39-6f85c13dc55e> in load_data(filepath)
#       6     Loads diabetes data into a DataFrame from a string filepath.
#       7     """
# ----> 8     df = pd.read_csv(filepath, index_col='Patient number')
#       9     return df
#      10
#
# ...

# %%
automl = setup(data = df, target = 'Churn',  preprocess=True, fold_shuffle=True, imputation_type='iterative')
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            23:36:03
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                              Data Type
# tenure                         Numeric
# PhoneService               Categorical
# Contract                   Categorical
# MonthlyCharges                 Numeric
# TotalCharges                   Numeric
# Tenure_TotalCharges_ratio      Numeric
# TotalCharges_Tenure_ratio      Numeric
# Churn                            Label
# quit
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Read the documentation of setup to learn how to overwrite data types over the inferred types. setup function must run again before you continue modeling.

# %%
automl = setup(data = df, target = 'Churn', preprocess=False, fold_shuffle=True, imputation_type='iterative')
# Out:
# <style  type="text/css" >
# </style><table id="T_12298_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12298_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_12298_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_12298_row0_col1" class="data row0 col1" >8156</td>
#             </tr>
#             <tr>
#                         <th id="T_12298_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_12298_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_12298_row1_col1" class="data row1 col1" >Churn</td>
#             </tr>
#             <tr>
#                         <th id="T_12298_level0_row2" class="row_heading level0 row2" >2</th>
# ...
